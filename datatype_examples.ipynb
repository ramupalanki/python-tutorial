# %%
#assigning integer values, printing and then displaying its type
min_marks=35
print(min_marks)
print(type(min_marks))
# Out:
# 35
# <class 'int'>

# %%
#assigning integer values, printing and then displaying its type
max_marks=100
print(max_marks)
print(type(max_marks))
# Out:
# 100
# <class 'int'>

# %%
#assigning integer values, printing and then displaying its type
age=25
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
#assigning floating value, printing and then displaying its type
salary=100000.50
print(salary)
print(type(salary))
# Out:
# 100000.5
# <class 'float'>

# %%
#assigning floating value, printing and then displaying its type
monthly_salary=9000.50
print(monthly_salary)
print(type(monthly_salary))
# Out:
# 9000.5
# <class 'float'>

# %%
#assigning string value, printing and then displaying its type
company="XYZ"
print(company)
print(type(company))
# Out:
# XYZ
# <class 'str'>

# %%
#assigning string value, printing and then displaying its type
name_with_aphostrophy="it's Ramu"
print(name_with_aphostrophy)
print(type(name_with_aphostrophy))
# Out:
# it's Ramu
# <class 'str'>

# %%
#assigning string value, printing and then displaying its type
name="Ramu"
print(name)
print(type(name))
# Out:
# Ramu
# <class 'str'>

# %%
#assigning boolean values, printing and then displaying its type
dislike_python=False
print(dislike_python)
print(type(dislike_python))
# Out:
# False
# <class 'bool'>

# %%
#assigning boolean values, printing and then displaying its type
like_python=True
print(like_python)
print(type(like_python))
# Out:
# True
# <class 'bool'>

# %%
#creating list data type, printing and then displaying its type
fruits=["banana","Mango","Apple"]
print(fruits)
print(type(fruits))
# Out:
# ['banana', 'Mango', 'Apple']
# <class 'list'>

# %%
#creating tuple data type, printing and then displaying its type
names=("Ramu","Ravi","Raju")
print(names)
print(type(names))
# Out:
# ('Ramu', 'Ravi', 'Raju')
# <class 'tuple'>

# %%
#creating tuple data type, printing and then displaying its type
games=("cricket","shuttle","table tennis")
print(games)
print(type(games))
# Out:
# ('cricket', 'shuttle', 'table tennis')
# <class 'tuple'>

# %%
#creating set data type, printing and then displaying its type
types={"test", "oneday","T20"}
print(types)
print(type(types))
# Out:
# {'oneday', 'test', 'T20'}
# <class 'set'>

# %%
#creating dictionary data type, printing and then displaying its type
student_info ={"name":"Ramu","company":"XYZ"}
print(student_info)
print(type(student_info))
# Out:
# {'name': 'Ramu', 'company': 'XYZ'}
# <class 'dict'>

# %%
#converting string to integer
# 1. int("100")
# Before: "100" is a string (str).
# Conversion: int() converts a numeric string into an integer.
# After: 100 is an integer (int).
# Result: The value can now be used in integer arithmetic.
print(int("100"))
# Out:
# 100

# %%
#converting string to float
# 2. float("45.67")
# Before: "45.67" is a string (str).
# Conversion: float() converts a numeric string into a floating-point number.
# After: 45.67 is a float (float).
# Result: The value can now be used in decimal-number calculations.

print(float("45.67"))
# Out:
# 45.67

# %%
#converting integer to string
# 3. str(500)
# Before: 500 is an integer (int).
# Conversion: str() converts the number into text.
# After: "500" is a string (str).
# Result: The value is now treated as text rather than a number.
print(str(500))
# Out:
# 500

# %%
#converting integer to boolean
# 4. bool(1)
# Before: 1 is an integer (int).
# Conversion: bool() converts the value into a Boolean value.
# After: 1 becomes True because non-zero numbers are considered True.
# Result: The converted value can be used in Boolean conditions.
print(bool(1))
# Out:
# True

# %%
#converting tuple to list
# 5. list((1, 2, 3))
# Before: (1, 2, 3) is a tuple (tuple).
# Conversion: list() converts the tuple into a list.
# After: [1, 2, 3] is a list (list).
# Result: The values are now stored in a mutable collection.
print(list((1, 2, 3)))
# Out:
# [1, 2, 3]

# %%
#converting list to tuple
# 6. tuple([1, 2, 3])
# Before: [1, 2, 3] is a list (list).
# Conversion: tuple() converts the list into a tuple.
# After: (1, 2, 3) is a tuple (tuple).
# Result: The values are now stored in an immutable sequence.
print(tuple([1, 2, 3]))
# Out:
# (1, 2, 3)

# %%
# 7. set([1, 2, 2, 3])
# Before: [1, 2, 2, 3] is a list (list) containing a duplicate 2.
# Conversion: set() converts the list into a set.
# After: {1, 2, 3} is a set (set).
# Result: Duplicate values are automatically removed.
print(set([1, 2, 2, 3]))
# Out:
# {1, 2, 3}
