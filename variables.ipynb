# %%
name='It\'s Ramu Palanki'
print(name)
print(type(name))

# %%
ag2_e=-25
print(ag2_e)
print(type(ag2_e))
# Out:
# -25
# <class 'int'>

# %%
salary=10000.50
print(salary)
print(type(salary))
# Out:
# 10000.5
# <class 'float'>

# %%
like_python=False
print(like_python)
print(type(like_python))
# Out:
# False
# <class 'bool'>
